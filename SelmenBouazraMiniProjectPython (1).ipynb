# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read data from file cvs

# %%
df = pd.read_csv("Affairs.csv", encoding = "unicode_escape")

# %% [markdown]
# Data frame

# %%
df
# Out:
#      Unnamed: 0  affairs  gender   age  yearsmarried children  religiousness  \
# 0             4        0    male  37.0         10.00       no              3
# 1             5        0  female  27.0          4.00       no              4
# 2            11        0  female  32.0         15.00      yes              1
# 3            16        0    male  57.0         15.00      yes              5
# 4            23        0    male  22.0          0.75       no              2
# ..          ...      ...     ...   ...           ...      ...            ...
# 596        1938        1    male  22.0          1.50      yes              1
# 597        1941        7  female  32.0         10.00      yes              2
# 598        1954        2    male  32.0         10.00      yes              2
# 599        1959        2    male  22.0          7.00      yes              3
# 600        9010        1  female  32.0         15.00      yes              3
#
#      education  occupation  rating
# ...

# %% [markdown]
# Data frame first seven lines

# %%
df.head(7)
# Out:
#    Unnamed: 0  affairs  gender   age  yearsmarried children  religiousness  \
# 0           4        0    male  37.0         10.00       no              3
# 1           5        0  female  27.0          4.00       no              4
# 2          11        0  female  32.0         15.00      yes              1
# 3          16        0    male  57.0         15.00      yes              5
# 4          23        0    male  22.0          0.75       no              2
# 5          29        0  female  32.0          1.50       no              2
# 6          44        0  female  22.0          0.75       no              2
#
#    education  occupation  rating
# 0         18           7       4
# 1         14           6       4
# 2         12           1       4
# 3         18           6       5
# 4         17           6       3
# 5         17           5       5
# 6         12           1       3

# %% [markdown]
# data frame shape

# %%
df.shape
# Out:
# (601, 10)

# %% [markdown]
# Data frame last three lines

# %%
df.tail(3)
# Out:
#      Unnamed: 0  affairs  gender   age  yearsmarried children  religiousness  \
# 598        1954        2    male  32.0          10.0      yes              2
# 599        1959        2    male  22.0           7.0      yes              3
# 600        9010        1  female  32.0          15.0      yes              3
#
#      education  occupation  rating
# 598         17           6       5
# 599         18           6       2
# 600         14           1       5

# %% [markdown]
# Convert data frame to list

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'affairs',
#  'gender',
#  'age',
#  'yearsmarried',
#  'children',
#  'religiousness',
#  'education',
#  'occupation',
#  'rating']

# %% [markdown]
# Copy the data frame in new variable "df_copy"

# %%
df_copy=df.copy()

# %% [markdown]
# Filter data frame when gender is "female"

# %%
df_copy[df_copy.gender=="female"]
# Out:
#      Unnamed: 0  affairs  gender   age  yearsmarried children  religiousness  \
# 1             5        0  female  27.0          4.00       no              4
# 2            11        0  female  32.0         15.00      yes              1
# 5            29        0  female  32.0          1.50       no              2
# 6            44        0  female  22.0          0.75       no              2
# 8            47        0  female  32.0         15.00      yes              4
# ..          ...      ...     ...   ...           ...      ...            ...
# 589        1831        7  female  32.0         15.00      yes              3
# 590        1840        7  female  27.0          7.00      yes              4
# 592        1856        7  female  42.0         15.00      yes              2
# 597        1941        7  female  32.0         10.00      yes              2
# 600        9010        1  female  32.0         15.00      yes              3
#
#      education  occupation  rating
# ...

# %% [markdown]
# Filter data frame when "education" is between 16 and 14

# %%
df_copy[df_copy["education"].isin((16,14))]
# Out:
#      Unnamed: 0  affairs  gender   age  yearsmarried children  religiousness  \
# 1             5        0  female  27.0           4.0       no              4
# 7            45        0    male  57.0          15.0      yes              2
# 8            47        0  female  32.0          15.0      yes              4
# 9            49        0    male  22.0           1.5       no              4
# 14           86        0  female  27.0           4.0       no              4
# ..          ...      ...     ...   ...           ...      ...            ...
# 590        1840        7  female  27.0           7.0      yes              4
# 592        1856        7  female  42.0          15.0      yes              2
# 594        1929        3    male  32.0          10.0      yes              4
# 595        1935        7    male  47.0          15.0      yes              3
# 600        9010        1  female  32.0          15.0      yes              3
#
#      education  occupation  rating
# ...

# %%
df_copy2=df.copy()

# %% [markdown]
# Religiousness column description

# %%
df_copy2["religiousness"].describe()
# Out:
# count    601.000000
# mean       3.116473
# std        1.167509
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: religiousness, dtype: float64

# %% [markdown]
# Print the columns "education", "occupation", "rating" after filter data frame when gender is "male" and yearsmarried > 5 and don't have children

# %%
df_copy.loc[(df_copy["gender"]=="male") & (df_copy["yearsmarried"]>5) & (df_copy["children"]=="no"), ["education", "occupation", "rating"]]
# Out:
#      education  occupation  rating
# 0           18           7       4
# 64          20           6       4
# 115         20           6       5
# 117         18           6       4
# 278         20           6       4
# 340         20           6       5
# 404          9           3       1
# 405         18           5       5
# 412         12           4       3
# 447         14           5       4
# 549         18           4       2
# 567         16           5       5
# 578         14           6       2
# 587         18           6       5

# %% [markdown]
# Curve of rating by years of marriage

# %%
df.plot(x="rating", y="yearsmarried", kind="scatter")
# Out:
# <AxesSubplot: xlabel='rating', ylabel='yearsmarried'>

# %% [markdown]
# Data frame gender percentage

# %%
df["gender"].value_counts(normalize=True).plot.pie(legend=True,autopct='%1.0f%%', figsize=(7,7))
# Out:
# <AxesSubplot: ylabel='gender'>

# %% [markdown]
# Data frame is has children percentage

# %%
df["children"].value_counts(normalize=True).plot.pie(legend=True,autopct='%1.0f%%', figsize=(7,7))
# Out:
# <AxesSubplot: ylabel='children'>

# %% [markdown]
# Statistical rating table by years of marriage

# %%
df.plot(x="rating", y="yearsmarried", kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# Curve of affairs by age

# %%
df.groupby("affairs")["age"].plot()
# Out:
# affairs
# 0     AxesSubplot(0.125,0.11;0.775x0.77)
# 1     AxesSubplot(0.125,0.11;0.775x0.77)
# 2     AxesSubplot(0.125,0.11;0.775x0.77)
# 3     AxesSubplot(0.125,0.11;0.775x0.77)
# 7     AxesSubplot(0.125,0.11;0.775x0.77)
# 12    AxesSubplot(0.125,0.11;0.775x0.77)
# Name: age, dtype: object
